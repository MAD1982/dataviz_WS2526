# %% [markdown]
# # VL 2 Statische Visualisierung, Übung

# %% [markdown]
# Namen eintragen
#
# - 1) Vorname Nachname
# - 2) Vorname Nachname

# %% [markdown]
# # Setup

# %%
# Installation der benötigten Pakete
# %pip install gapminder pandas plotnine
# Out:
# Requirement already satisfied: gapminder in c:\users\matthias\anaconda3\lib\site-packages (0.1)
# Requirement already satisfied: pandas in c:\users\matthias\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: plotnine in c:\users\matthias\anaconda3\lib\site-packages (0.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\matthias\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matthias\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matthias\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matthias\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\users\matthias\anaconda3\lib\site-packages (from plotnine) (3.9.2)
# Requirement already satisfied: mizani~=0.14.0 in c:\users\matthias\anaconda3\lib\site-packages (from plotnine) (0.14.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\matthias\anaconda3\lib\site-packages (from plotnine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\matthias\anaconda3\lib\site-packages (from plotnine) (0.14.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matthias\anaconda3\lib\site-packages (from matplotlib>=3.8.0->plotnine) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\matthias\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\matthias\anaconda3\lib\site-packages (from statsmodels>=0.14.5->plotnine) (0.5.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importiere benötigte Bibliotheken
import pandas as pd
from plotnine import *
from gapminder import gapminder

# %% [markdown]
# # Gapminder Daten laden

# %%
# Zeige die ersten Zeilen des Datensatzes

# Daten für Deutschland filtern

# %%
# Beschreibe die Daten

# Deutschland Daten beschreiben

# %%
# Kernel density plot 2007 für Lebenserwartung
data_2007 = gapminder[gapminder['year'] == 2007]
(
    ggplot(data_2007, aes(x='lifeExp', fill='continent')) +
    geom_density(alpha=0.5) +
    labs(title='Kernel Density Plot der Lebenserwartung im Jahr 2007',
         x='Lebenserwartung',
         y='Dichte') +
    theme_minimal()
)

# Kernel density plot 2007 für Lebenserwartung
data_2007 = gapminder[gapminder['year'] == 2007]
(
    ggplot(data_2007, aes(x='gdpPercap', fill='continent')) +
    geom_density(alpha=0.5) +
    labs(title='Kernel Density Plot BIP/Kopf im Jahr 2007',
         x='Lebenserwartung',
         y='Dichte') +
    theme_minimal()
)

# %% [markdown]
# # Aufgabe 1

# %% [markdown]
# Frage: Wie hängen Einkommen und Lebenserwartung zusammen?
#
# Ziel: Verständnis von Aesthetic Mapping und Scale Transformation

# %% [markdown]
# Hinweise
# - Scatterplot verwenden
# - x = gdpPercap
# - y = lifeExp
# - Farbe = continent
# - Skalierung (scale_x_log10())

# %% [markdown]
# 📊 Interpretation:

# %% [markdown]
# # Aufgabe 2

# %% [markdown]
# Frage: Wie unterscheiden sich die Kontinente in der Lebenserwartung (2007)?
#
# Ziel: Lernen, wie Geoms und Grouping Verteilungen sichtbar machen.

# %% [markdown]
# Hinweise
# - Filtere: year == 2007
# - Nutze Boxplots
# - Färbe nach continent
# - Interpretiere Median, Spannweite, Ausreißer

# %% [markdown]
# 📈 Interpretation:

# %% [markdown]
# # Aufgabe 3

# %% [markdown]
# Frage: Wie hat sich die Lebenserwartung der Länder (nach Kontinenten) über die Zeit verändert?
#
# Ziel: Lernen, wie Facets Teilmengen der Daten trennen und Muster sichtbar machen.

# %% [markdown]
# Hinweise:
# - x = year
# - y = lifeExp
# - group = country, color = continent
# - Facettiere mit facet_wrap(~continent)

# %% [markdown]
# 📊 Interpretation: Alle Kontinente zeigen steigende Lebenserwartung, Afrika jedoch auf niedrigerem Niveau.

# %% [markdown]
# ##### Frage: Was kann an dieser Visualisierung verbessert werden?

# %% [markdown]
# # Aufgabe 4

# %% [markdown]
# Frage: Wie verändern sich die globalen Muster von Wohlstand und Lebenserwartung über die Jahrzehnte hinweg? Sind die Unterschiede zwischen Kontinenten konstant, oder nähern sich Länder im Laufe der Zeit an?
#
# Ziel: Verstehen, wie Änderungen von Zusammenhängen im Zeitverlauf visualisiert werden können – und wie man mit Facets mehrere Zeitabschnitte gleichzeitig visualisieren kann.

# %% [markdown]
# Hinweise:
# - x = gdpPercap
# - y = lifeExp
# - color = continent
# - Verwende scale_x_log10()
# - Nutze Facets nach Jahr (facet_wrap('~year')), um mehrere kleine Scatterplots zu erzeugen
# - Verwende theme_minimal() für eine klare Darstellung

# %% [markdown]
# 📊 Interpretation:
